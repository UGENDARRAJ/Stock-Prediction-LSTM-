# %%
# Importing the libraries

import math
import pandas as pd
import yfinance as yf
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = yf.download('AAPL', start='2012-01-01', end='2019-12-17')
# Lets show the data
print(df)
# Out:
# c:\Users\tmachine\AppData\Local\Programs\Python\Python39\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2012-01-03  14.621429  14.732143  14.607143  14.686786  12.449693  302220800
# 2012-01-04  14.642857  14.810000  14.617143  14.765714  12.516595  260022000
# 2012-01-05  14.819643  14.948214  14.738214  14.929643  12.655557  271269600
# 2012-01-06  14.991786  15.098214  14.972143  15.085714  12.787854  318292800
# 2012-01-09  15.196429  15.276786  15.048214  15.061786  12.767572  394024400
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-10  67.150002  67.517502  66.464996  67.120003  65.390450   90420400
# 2019-12-11  67.202499  67.775002  67.125000  67.692497  65.948189   78756800
# 2019-12-12  66.945000  68.139999  66.830002  67.864998  66.116264  137310400
# 2019-12-13  67.864998  68.824997  67.732498  68.787498  67.014977  133587600
# 2019-12-16  69.250000  70.197502  69.245003  69.964996  68.162132  128186000
#
# [2002 rows x 6 columns]

# %%
# Get the number of rows and columns in the dataset
df.shape
# Out:
# (2002, 6)

# %%
#Visualize the closng price history
plt.plot(df['Close'])
plt.xlabel('Data')
plt.ylabel('Close Price USD($)')
plt.show()

# %%
#Create a new dataframe with only the 'Close Column'
data = df.filter(['Close'])
#Convert the dataframe to numpy array
dataset = data.values
#Get the number of rows to trains the model on
Training_data_inc = math.ceil(len(dataset)*0.8)
Training_data_inc
# Out:
# 1602

# %%
#Scale the Data
